# %% [markdown]
# Project by : Ionas Andreea and Mihu Octavian.

# %%
import pandas as pd
# Load test.csv
test_data = pd.read_csv('test.csv')

# Load train.csv
train_data = pd.read_csv('training.csv')

# %% [markdown]
# Display descriptive statistics for numerical columns in the "test.csv" file.

# %%
print("Test Data Description:")
print(test_data.describe())
# Out:
# Test Data Description:
#           patient_id  patient_zip3  patient_age          bmi    population  \
# count    5792.000000   5792.000000  5792.000000  1777.000000   5792.000000
# mean   549946.787983    570.217887    59.274862    28.900073  20266.872152
# std    260988.833446    275.314510    13.076323     5.609491  13694.738314
# min    100266.000000    101.000000    18.000000    14.000000    829.515152
# 25%    320284.500000    329.000000    50.000000    24.600000   8863.550000
# 50%    553042.000000    554.000000    59.000000    28.150000  18711.016665
# 75%    778552.250000    836.000000    67.000000    32.860000  28996.772730
# max    999890.000000    996.000000    91.000000    43.900000  71374.131580
#
#             density   age_median  age_under_10  age_10_to_19      age_20s  \
# count   5792.000000  5792.000000   5792.000000   5792.000000  5792.000000
# mean    1510.471786    40.575472     11.119250     12.919191    13.218348
# ...

# %% [markdown]
# Display descriptive statistics for numerical columns in the "train.csv" file.

# %%
print("Train Data Description:")
print(train_data.describe())
# Out:
# Train Data Description:
#           patient_id  patient_zip3   patient_age          bmi    population  \
# count   12906.000000  12906.000000  12906.000000  3941.000000  12905.000000
# mean   547381.196033    573.754300     59.183326    28.984539  20744.441237
# std    260404.959974    275.447534     13.335216     5.696906  13886.903756
# min    100063.000000    101.000000     18.000000    14.000000    635.545455
# 25%    321517.000000    331.000000     50.000000    24.660000   9463.896552
# 50%    543522.000000    554.000000     59.000000    28.190000  19154.190480
# 75%    772671.750000    846.000000     67.000000    32.920000  30021.278690
# max    999896.000000    999.000000     91.000000    85.000000  71374.131580
#
#             density    age_median  age_under_10  age_10_to_19       age_20s  \
# count  12905.000000  12905.000000  12905.000000  12905.000000  12905.000000
# mean    1581.950419     40.502259     11.122784     12.945265     13.290376
# ...

# %% [markdown]
# Display statistical summaries for numerical columns in the "test.csv" file.

# %%
print("Test Data Info:")
test_data.info()
# Out:
# Test Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5792 entries, 0 to 5791
# Data columns (total 82 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   patient_id                             5792 non-null   int64
#  1   patient_race                           2891 non-null   object
#  2   payer_type                             5032 non-null   object
#  3   patient_state                          5771 non-null   object
#  4   patient_zip3                           5792 non-null   int64
#  5   patient_age                            5792 non-null   int64
#  6   patient_gender                         5792 non-null   object
#  7   bmi                                    1777 non-null   float64
#  8   breast_cancer_diagnosis_code           5792 non-null   object
#  9   breast_cancer_diagnosis_desc           5792 non-null   object
# ...

# %%
print("Train Data Info:")
train_data.info()
# Out:
# Train Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12906 entries, 0 to 12905
# Data columns (total 83 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   patient_id                             12906 non-null  int64
#  1   patient_race                           6521 non-null   object
#  2   payer_type                             11103 non-null  object
#  3   patient_state                          12855 non-null  object
#  4   patient_zip3                           12906 non-null  int64
#  5   patient_age                            12906 non-null  int64
#  6   patient_gender                         12906 non-null  object
#  7   bmi                                    3941 non-null   float64
#  8   breast_cancer_diagnosis_code           12906 non-null  object
#  9   breast_cancer_diagnosis_desc           12906 non-null  object
# ...

# %% [markdown]
# Calculate the count of patients for each race in the "test.csv" dataset using the 'patient_race' column. It's evident that the number of white patients is notably higher, nearly equivalent to the total of all other races combined.
# From the two cells below it appears that the data from test and train are quite balanced.

# %%
race_counts_test = test_data['patient_race'].value_counts()
(race_counts_test)
# Out:
# patient_race
# White       1606
# Black        510
# Hispanic     347
# Other        273
# Asian        155
# Name: count, dtype: int64

# %%
race_counts_train = train_data['patient_race'].value_counts()
(race_counts_train)
# Out:
# patient_race
# White       3588
# Black       1056
# Hispanic     829
# Other        683
# Asian        365
# Name: count, dtype: int64

# %% [markdown]
# Group the data by 'patient_race' and count the occurrences of 'breast_cancer_diagnosis_code' in the "test.csv" dataset. The resulting plot illustrates the distribution of breast cancer diagnoses across different races. This visualization allows us to observe the predominant diagnosis code for each race.

# %%
breast_cancer_by_race_test = test_data.groupby(['patient_race', 'breast_cancer_diagnosis_code']).size().unstack(fill_value=0)
import matplotlib.pyplot as plt
breast_cancer_by_race_test.plot(kind='bar', stacked=True, figsize=(12, 8))
plt.title('Number of Breast Cancer Diagnoses by Race (Test Data)')
plt.xlabel('Patient Race')
plt.ylabel('Number of Diagnoses')
plt.show()

# %% [markdown]
# Group the data by 'breast_cancer_diagnosis_code' and 'breast_cancer_diagnosis_desc', then count the occurrences to determine which breast cancer diagnosis code is the most common and its corresponding description. This analysis provides insight into the prevalence of different types of breast cancer diagnoses.

# %%
diagnosis_counts = test_data.groupby(['breast_cancer_diagnosis_code', 'breast_cancer_diagnosis_desc']).size()
pd.set_option('display.max_rows', 200)
diagnosis_counts_sorted = diagnosis_counts.sort_values(ascending=False)
print(diagnosis_counts_sorted)
# Out:
# breast_cancer_diagnosis_code  breast_cancer_diagnosis_desc
# 1749                          Malignant neoplasm of breast (female), unspecified              906
# C50911                        Malignant neoplasm of unsp site of right female breast          817
# C50912                        Malignant neoplasm of unspecified site of left female breast    763
# C50919                        Malignant neoplasm of unsp site of unspecified female breast    652
# C50411                        Malig neoplm of upper-outer quadrant of right female breast     421
# C50412                        Malig neoplasm of upper-outer quadrant of left female breast    406
# C50812                        Malignant neoplasm of ovrlp sites of left female breast         194
# C50811                        Malignant neoplasm of ovrlp sites of right female breast        193
# 1744                          Malignant neoplasm of upper-outer quadrant of female breast     169
# ...

# %% [markdown]
# Group the data by 'patient_race' and count the occurrences of 'metastatic_cancer_diagnosis_code' in the "test.csv" dataset. This allows us to observe which metastatic cancer diagnosis code is dominant for each race.
# We can see that C773 is the most used code, regardless of patient_race.

# %%
metastatic_cancer_by_race_test = test_data.groupby('patient_race')['metastatic_cancer_diagnosis_code'].value_counts()
pd.set_option('display.max_rows', 200)
(metastatic_cancer_by_race_test)
# Out:
# patient_race  metastatic_cancer_diagnosis_code
# Asian         C773                                 84
#               C7951                                23
#               C779                                 10
#               C7800                                 8
#               C787                                  5
#               C7981                                 4
#               C7931                                 4
#               C7989                                 3
#               C799                                  3
#               C792                                  2
#               C770                                  2
#               C7802                                 2
#               C7900                                 1
#               C778                                  1
#               C771                                  1
#               C7949                                 1
# ...

# %% [markdown]
# Calculate the avarage age of the patients.

# %%
mean_age_test = test_data['patient_age'].mean()
print("Mean Age of Patients (Test Data):", mean_age_test)
# Out:
# Mean Age of Patients (Test Data): 59.27486187845304

# %% [markdown]
# From the graph below we can see that most diagnosed people are between 41 and 60 years old.

# %%
import pandas as pd
import matplotlib.pyplot as plt
bins = [0, 20, 40, 60, 80, 100]
labels = ['0 - 20', '21 - 40', '41 - 60', '61 - 80', '81 - 100']
age_category_counts = pd.cut(test_data['patient_age'], bins=bins, labels=labels, right=False).value_counts()
age_category_counts.plot.bar(figsize=(10, 6), color='skyblue')
plt.title('Number of Patients in Each Age Category')
plt.xlabel('Age Category')
plt.ylabel('Number of Patients')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Calculate the count of breast cancer diagnoses by gender in the "test.csv" dataset. It's worth noting that all patients in the dataset are women, rendering the 'patient_gender' column redundant and can be dropped as it provides no useful information.

# %%
gender_counts_test = test_data[test_data['breast_cancer_diagnosis_code'].notnull()]['patient_gender'].value_counts()
print("Breast Cancer Diagnoses by Gender (Test Data):")
(gender_counts_test)
# Out:
# Breast Cancer Diagnoses by Gender (Test Data):
# patient_gender
# F    5792
# Name: count, dtype: int64

# %% [markdown]
# We want to analyze the number of patients for each state, noting that the highest number is significantly in CA (California).

# %%
state_counts_train = train_data['patient_state'].value_counts()
print(state_counts_train)
# Out:
# patient_state
# CA    2438
# TX    1155
# NY    1041
# MI     858
# IL     782
# OH     754
# FL     609
# GA     551
# PA     483
# MN     377
# CO     371
# VA     365
# IN     317
# KY     259
# AZ     229
# WI     212
# WA     200
# NC     186
# MO     160
# NM     141
# LA     139
# TN     112
# SC     110
# ID      93
# OK      93
# OR      89
# IA      86
# MS      76
# MD      71
# AR      63
# NV      62
# KS      50
# AL      50
# MT      45
# NE      40
# UT      36
# DE      33
# WV      27
# HI      21
# NJ      21
# DC      20
# SD       8
# ND       6
# AK       6
# WY       4
# CT       2
# PR       1
# RI       1
# NH       1
# MA       1
# Name: count, dtype: int64

# %% [markdown]
# Here we examine the relationship between the first three digits of the zip code ('patient_zip3'), patient race ('patient_race'), and breast cancer diagnosis code ('breast_cancer_diagnosis_code') in the "test.csv" dataset.

# %%
t = test_data.groupby(['patient_zip3', 'patient_race', 'breast_cancer_diagnosis_code' ]).size()
pd.set_option('display.max_rows', 10)
zip_counts_sorted = t.sort_values(ascending=False)
(zip_counts_sorted)
# Out:
# patient_zip3  patient_race  breast_cancer_diagnosis_code
# 802           White         C50911                          12
#                             C50912                          12
# 800           White         C50912                           9
# 900           Hispanic      C50919                           7
# 142           White         1749                             7
#                                                             ..
# 424           Other         1749                             1
# 423           White         1749                             1
#               Other         C50912                           1
# 422           White         C50512                           1
# 992           White         C50812                           1
# Length: 2339, dtype: int64

# %% [markdown]
# Group the test data by payer type and patient state, and count occurrences. Convert the Series to a DataFrame and
# reset index to make it suitable for plotting. Create pivot table to separate patient counts by payer type.
# For the cases where there is no payer_type, in the future we can train a module to complete those free spaces with the most use payer_type from that state.
# We can see that most people have as payer_type "COMMERCIAL".

# %%
import matplotlib.pyplot as plt

t = train_data.groupby(['payer_type', 'patient_state']).size()
state_counts_sorted = t.sort_values(ascending=False)
state_counts_sorted_df = state_counts_sorted.reset_index(name='Patient Count')
pivot_table = state_counts_sorted_df.pivot(index='patient_state', columns='payer_type', values='Patient Count')


plt.figure(figsize=(14, 10))
bottom = None
colors = ['b', 'g', 'r']

for payer_type in pivot_table.columns:
    if bottom is None:
        plt.bar(pivot_table.index, pivot_table[payer_type], label=payer_type, color=colors.pop(0))
        bottom = pivot_table[payer_type]
    else:
        plt.bar(pivot_table.index, pivot_table[payer_type], bottom=bottom, label=payer_type, color=colors.pop(0))
        bottom += pivot_table[payer_type]

plt.xlabel('Patient State')
plt.ylabel('Patient Count')
plt.title('Patient Counts by Payer Type and Patient State')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# In this graph we can see the distribution of people by state according to race.

# %%
import matplotlib.pyplot as plt

t = train_data.groupby(['patient_race', 'patient_state']).size()
state_counts_sorted = t.sort_values(ascending=False)
state_counts_sorted_df = state_counts_sorted.reset_index(name='Patient Count')
pivot_table = state_counts_sorted_df.pivot(index='patient_state', columns='patient_race', values='Patient Count')

plt.figure(figsize=(14, 10))
bottom = None
colors = ['b', 'g', 'r', 'c', 'm', 'y']  

for patient_race in pivot_table.columns:
    if bottom is None:
        plt.bar(pivot_table.index, pivot_table[patient_race], label=patient_race, color=colors.pop(0))
        bottom = pivot_table[patient_race]
    else:
        plt.bar(pivot_table.index, pivot_table[patient_race], bottom=bottom, label=patient_race, color=colors.pop(0))
        bottom += pivot_table[patient_race]

plt.xlabel('Patient State')
plt.ylabel('Patient Count')
plt.title('Patient Counts by Patient Race and Patient State (TRAIN DARA)')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# This plot visualizes how payer types are distributed among different patient races, providing insights into any potential disparities or trends across racial groups in terms of healthcare coverage.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.countplot(x='payer_type', hue='patient_race', data = train_data)
plt.title('Relationship between Patient Race and Payer Type (TRAIN DATA)')
plt.xlabel('Payer Type')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Patient Race')
plt.tight_layout()
plt.show()

# %% [markdown]
# From this graph it appears that the majority of people diagnosed with an age of over 60 years have as payer_type "MEDICARE ADVANTAGE".
# Using this information we could complete the missing cells in the "payer_type" column for people over 60 years old with "MEDICARE ADVANTAGE" and for the others we could complete with "Unknown".

# %%
import seaborn as sns
import matplotlib.pyplot as plt

mean_age_by_payer_type = train_data.groupby('payer_type')['patient_age'].mean().reset_index()
plt.figure(figsize=(10, 6))
sns.barplot(x='payer_type', y='patient_age', data=mean_age_by_payer_type)
plt.title('Average Patient Age by Payer Type')
plt.xlabel('Payer Type')
plt.ylabel('Average Patient Age')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# We can see from the chart that most of the variations are in N02.
# From the graphs made below, we cannot see a notable difference that could help us, so we could drop the 3 columns.

# %%
import matplotlib.pyplot as plt
top_diagnosis_codes = test_data['metastatic_cancer_diagnosis_code'].value_counts().head(15).index
subset_data = test_data[test_data['metastatic_cancer_diagnosis_code'].isin(top_diagnosis_codes)]

mean_ozone_by_diagnosis = subset_data.groupby('metastatic_cancer_diagnosis_code')['Ozone'].mean()
mean_pm25_by_diagnosis = subset_data.groupby('metastatic_cancer_diagnosis_code')['PM25'].mean()
mean_no2_by_diagnosis = subset_data.groupby('metastatic_cancer_diagnosis_code')['N02'].mean()

plt.figure(figsize=(12, 6))

plt.plot(mean_ozone_by_diagnosis.index, mean_ozone_by_diagnosis.values, label='Ozone', color='blue', marker='o')
plt.plot(mean_pm25_by_diagnosis.index, mean_pm25_by_diagnosis.values, label='PM2.5', color='red', marker='o')
plt.plot(mean_no2_by_diagnosis.index, mean_no2_by_diagnosis.values, label='NO2', color='green', marker='o')

plt.title('Mediile Concentrațiilor de Ozon, PM2.5 și NO2 pentru Cele Mai Frecvente Coduri de Diagnostic (TEST DATA)')
plt.xlabel('Metastatic Cancer Diagnosis Code')
plt.ylabel('Medie Concentrație')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
top_diagnosis_codes = train_data['metastatic_cancer_diagnosis_code'].value_counts().head(15).index
subset_data = train_data[train_data['metastatic_cancer_diagnosis_code'].isin(top_diagnosis_codes)]

mean_ozone_by_diagnosis = subset_data.groupby('metastatic_cancer_diagnosis_code')['Ozone'].mean()
mean_pm25_by_diagnosis = subset_data.groupby('metastatic_cancer_diagnosis_code')['PM25'].mean()
mean_no2_by_diagnosis = subset_data.groupby('metastatic_cancer_diagnosis_code')['N02'].mean()

plt.figure(figsize=(12, 6))

plt.plot(mean_ozone_by_diagnosis.index, mean_ozone_by_diagnosis.values, label='Ozone', color='blue', marker='o')
plt.plot(mean_pm25_by_diagnosis.index, mean_pm25_by_diagnosis.values, label='PM2.5', color='red', marker='o')
plt.plot(mean_no2_by_diagnosis.index, mean_no2_by_diagnosis.values, label='NO2', color='green', marker='o')

plt.title('Mediile Concentrațiilor de Ozon, PM2.5 și NO2 pentru Cele Mai Frecvente Coduri de Diagnostic (TRAIN DATA)')
plt.xlabel('Metastatic Cancer Diagnosis Code')
plt.ylabel('Medie Concentrație')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Identify the 15 most frequent breast cancer diagnosis codes. Filter the data to include only these breast cancer diagnosis codes. Group the filtered data by breast_cancer_diagnosis_code and metastatic_cancer_diagnosis_code, then count occurrences. Notably, C773 and C7951 emerge as the most common metastatic codes observed.

# %%
import seaborn as sns

top_breast_codes = test_data['breast_cancer_diagnosis_code'].value_counts().head(15).index
filtered_data = test_data[test_data['breast_cancer_diagnosis_code'].isin(top_breast_codes)]
count_by_diagnosis = filtered_data.groupby(['breast_cancer_diagnosis_code', 'metastatic_cancer_diagnosis_code']).size()
count_by_diagnosis = count_by_diagnosis.unstack().fillna(0)

plt.figure(figsize=(12, 8))
sns.heatmap(count_by_diagnosis, cmap='YlGnBu', annot=True, fmt='g', linewidths=0.5)
plt.title('Count of Metastatic Cancer Diagnosis by Breast Cancer Diagnosis (Top 15)')
plt.xlabel('Metastatic Cancer Diagnosis Code')
plt.ylabel('Breast Cancer Diagnosis Code')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# See the relation between the metastatic_cancer_diagnosis_code and the age of the patient.

# %%
age_stats_by_metastatic_code = test_data.groupby('metastatic_cancer_diagnosis_code')['patient_age'].mean()
print(age_stats_by_metastatic_code)
# Out:
# metastatic_cancer_diagnosis_code
# C770     59.560606
# C771     60.385714
# C772     58.333333
# C773     58.388206
# C774     50.000000
#            ...
# C7972    75.000000
# C7981    61.397059
# C7982    68.000000
# C7989    59.351190
# C799     61.871795
# Name: patient_age, Length: 36, dtype: float64

# %% [markdown]
# We can see which payer_type has the higher DiagPeriodL9D.

# %%
diag_period_by_payer = train_data.groupby('payer_type')['DiagPeriodL90D'].mean()
print(diag_period_by_payer)
# Out:
# payer_type
# COMMERCIAL            0.598806
# MEDICAID              0.610354
# MEDICARE ADVANTAGE    0.642286
# Name: DiagPeriodL90D, dtype: float64

# %%
contingency_table = pd.crosstab(train_data['payer_type'], train_data['DiagPeriodL90D'])
print(contingency_table)
# Out:
# DiagPeriodL90D         0     1
# payer_type
# COMMERCIAL          2420  3612
# MEDICAID            1001  1568
# MEDICARE ADVANTAGE   895  1607

# %% [markdown]
# From the graphs made below, we can see that "COMMERCIAL" has the highest number of diagnoses, but among the other 2, a notable difference cannot be obtained.

# %%
contingency_table.plot(kind='bar', figsize=(12, 8))
plt.title('Distribution of DiagPeriodL90D by Payer Type')
plt.xlabel('Payer Type')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='DiagPeriodL90D', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# From this graph we can see that most patients who have cancer with code 1749 are not diagnosed in less than 90 days and patients who have cancer with codes C50919, C50912, C50911, C5041 and C504111 are often diagnosed in less than 90 days.

# %%
import matplotlib.pyplot as plt
import pandas as pd
counts = train_data.groupby(['breast_cancer_diagnosis_code', 'DiagPeriodL90D']).size().unstack(fill_value=0)
counts.plot(kind='bar', stacked=True, figsize=(10, 6))
plt.title('Frequency of cancer types for each value of DiagPeriodL90D')
plt.xlabel('Breast Cancer Diagnosis Code')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='DiagPeriodL90D')
plt.tight_layout()
plt.show()

# %% [markdown]
# From this graph it appears that quite a large part of the patients who have the code at metastatic_cancer_diagnosis_code C773 are diagnosed in less than 90 days. For the others types is not clear.

# %%
import matplotlib.pyplot as plt
import pandas as pd
counts = train_data.groupby(['metastatic_cancer_diagnosis_code', 'DiagPeriodL90D']).size().unstack(fill_value=0)
counts.plot(kind='bar', stacked=True, figsize=(10, 6))
plt.title('Frequency of cancer types for each value of DiagPeriodL90D')
plt.xlabel('Metastatic Cancer Diagnosis Code')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='DiagPeriodL90D')
plt.tight_layout()
plt.show()

# %% [markdown]
# Calculate the mean of 'DiagPeriodL90D' grouped by 'patient_race' in the train_data dataset. This provides insights into the average diagnosis period across different patient races.

# %%
diag_period_stats_by_race = train_data.groupby('patient_race')['DiagPeriodL90D'].mean()
print(diag_period_stats_by_race)
# Out:
# patient_race
# Asian       0.630137
# Black       0.613636
# Hispanic    0.632087
# Other       0.626647
# White       0.659142
# Name: DiagPeriodL90D, dtype: float64

# %% [markdown]
# From this graph, no significant differences can be observed according to race.

# %%
import matplotlib.pyplot as plt
diag_period_stats_by_race = train_data.groupby('patient_race')['DiagPeriodL90D'].mean()
plt.figure(figsize=(10, 6))
diag_period_stats_by_race.plot(kind='bar', color='skyblue')
plt.title('Mean of DiagPeriodL90D after race')
plt.xlabel('Race')
plt.ylabel('Mean of DiagPeriodL90D')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
pivot_data = train_data.pivot_table(index='patient_race', columns='DiagPeriodL90D', aggfunc='size', fill_value=0)

plt.figure(figsize=(10, 6))
pivot_data.plot(kind='bar', stacked=True, color=['lightblue', 'orange'])
plt.title('DiagPeriodL90D for each race')
plt.xlabel('Race')
plt.ylabel('Number of patients')
plt.xticks(rotation=45)
plt.legend(['0', '1'], title='DiagPeriodL90D')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# Looking at the data below, no significant differences can be observed between the people diagnosed in less than 90 days and the others, from the same income category.

# %%
mean_diag_period_under_5k = train_data.groupby('DiagPeriodL90D')['income_household_under_5'].mean()
mean_diag_period_over_150k = train_data.groupby('DiagPeriodL90D')['income_household_150_over'].mean()

print("Income under $5,000:", mean_diag_period_under_5k)
print("Income over $150,000:", mean_diag_period_over_150k)
# Out:
# Income under $5,000: DiagPeriodL90D
# 0    3.311661
# 1    3.244268
# Name: income_household_under_5, dtype: float64
# Income over $150,000: DiagPeriodL90D
# 0    16.492314
# 1    16.863207
# Name: income_household_150_over, dtype: float64

# %% [markdown]
# Visualize the mean of marital status variables (married, divorced, never_married, widowed) grouped by 'DiagPeriodL90D' in the train_data dataset using a grouped bar plot. This plot illustrates any potential differences between the diagnosis period ('DiagPeriodL90D') and marital status.

# %%
import matplotlib.pyplot as plt

diag_period_marital_mean = train_data.groupby('DiagPeriodL90D')[['married', 'divorced', 'never_married', 'widowed']].mean()
diag_period_marital_mean.plot(kind='bar', figsize=(10, 6))
plt.title('Mean Marital Status Variables by DiagPeriodL90D')
plt.xlabel('DiagPeriodL90D')
plt.ylabel('Mean')
plt.xticks(rotation=0)
plt.legend(title='Marital Status')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# Visualize the mean of the 'density' variable grouped by 'DiagPeriodL90D' in the train_data dataset using a bar plot. This plot illustrates any potential relationship between the diagnosis period ('DiagPeriodL90D') an  density.

# %%
import matplotlib.pyplot as plt
diag_period_density_mean = train_data.groupby('DiagPeriodL90D')[['density']].mean()
diag_period_density_mean.plot(kind='bar', figsize=(10, 6))
plt.title('Mean Deansity Variables by DiagPeriodL90D')
plt.xlabel('DiagPeriodL90D')
plt.ylabel('Mean')
plt.xticks(rotation=0)
plt.legend(title='Density')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# See which of the metastatic_cancer_diagnosis_code are most seen.

# %%
metastatic_code_counts = train_data['metastatic_cancer_diagnosis_code'].value_counts()
print("Top 10 Most Seen Metastatic Cancer Diagnosis Codes:")
print(metastatic_code_counts.head(10))
# Out:
# Top 10 Most Seen Metastatic Cancer Diagnosis Codes:
# metastatic_cancer_diagnosis_code
# C773     7052
# C7951    1842
# C779      764
# C7981     467
# C7800     414
# C787      362
# C7989     344
# C799      282
# C7931     282
# C792      166
# Name: count, dtype: int64

# %% [markdown]
# Visualize the distribution of patients with metastatic cancer diagnosis code C773 by race in the train_data dataset using a bar plot. This plot illustrates the mean representation of different races among patients diagnosed with metastatic cancer code C773.

# %%
import matplotlib.pyplot as plt
metastatic_C773_data = train_data[train_data['metastatic_cancer_diagnosis_code'] == 'C773']
race_counts = metastatic_C773_data[['race_white', 'race_black', 'race_asian', 'race_multiple', 'hispanic']].mean()
plt.figure(figsize=(10, 6))
race_counts.plot(kind='bar', color=['blue', 'orange', 'green', 'red'])
plt.title('Distribution of Patients with Metastatic Cancer Diagnosis Code C773 by Race')
plt.xlabel('Race')
plt.ylabel('Mean')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# This code filters the train_data to include specific race categories ('race_white', 'race_asian', 'race_black', 'race_multiple') along with 'DiagPeriodL90D' and 'payer_type'. It then groups the filtered data by these variables and calculates the sum. Finally, it visualizes the relationship between race categories, diagnosis period (DiagPeriodL90D), and payer type using a heatmap. The heatmap illustrates the summed values for each combination of diagnosis period, payer type, and race category.

# %%
import seaborn as sns

race_categories = ['race_white', 'race_asian', 'race_black', 'race_multiple']
filtered_data = train_data[['DiagPeriodL90D', 'payer_type'] + race_categories]
if filtered_data.empty:
    print("No data available for the specified race categories.")
else:
    grouped_data = filtered_data.groupby(['DiagPeriodL90D', 'payer_type']).sum()
    plt.figure(figsize=(12, 8))
    sns.heatmap(grouped_data, cmap='Blues', annot=True, fmt='.2f', linewidths=0.5)
    plt.title('Relationship between Race Categories, DiagPeriodL90D, and Payer Type')
    plt.xlabel('Payer Type')
    plt.ylabel('DiagPeriodL90D')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# With 8965 empty values out of a total of 12906 in the 'bmi' column, it's a significant portion of missing data. Dropping the column entirely might result in loss of potentially valuable information, especially if 'bmi' is expected to be an important feature.
#
# From the graph it can be seen that the majority of patience have a bmi between 26 and 30, but there are no considerable differences between the other bmi categories in conjunction with other columns.
#
# BUT after evaluating the data, we came to the conclusion that completing the missing values ​​would not bring a remarkable gain to the final goal, so we will drop the BMI column.

# %%
import pandas as pd
import matplotlib.pyplot as plt
bins = [0, 20, 25, 30, 35, 40, 100]
labels = ['0 - 20', '21 - 25', '26 - 30', '31 - 35', '36 - 40', '41+']
bmi_category_counts = pd.cut(train_data['bmi'], bins=bins, labels=labels, right=False).value_counts()
bmi_category_counts.plot.bar(figsize=(10, 6), color='lightgreen')
plt.title('Number of Patients in Each BMI Category')
plt.xlabel('BMI Category')
plt.ylabel('Number of Patients')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
bins = [0, 20, 25, 30, 35, 40, 100]
labels = ['0 - 20', '21 - 25', '26 - 30', '31 - 35', '36 - 40', '41+']
train_data['bmi_category'] = pd.cut(train_data['bmi'], bins=bins, labels=labels, right=False)
bmi_diag_counts = train_data.groupby(['bmi_category', 'DiagPeriodL90D'], observed=False).size().unstack(fill_value=0)
bmi_diag_counts.plot(kind='bar', figsize=(12, 8), width=0.8)
plt.title('Number of Patients by BMI Category and DiagPeriodL90D')
plt.xlabel('BMI Category')
plt.ylabel('Number of Patients')
plt.xticks(rotation=45)
plt.legend(title='DiagPeriodL90D')
plt.tight_layout()
plt.show()

# %%
bmi_count = train_data['bmi'].notnull().sum()
print("Number of non-empty values in the 'bmi' column:", bmi_count)
total_values = len(train_data['bmi'])
print("Total number of values in the 'bmi' column:", total_values)
print(total_values - bmi_count)
# Out:
# Number of non-empty values in the 'bmi' column: 3941
# Total number of values in the 'bmi' column: 12906
# 8965

# %%
bmi_count = test_data['bmi'].notnull().sum()
print("Number of non-empty values in the 'bmi' column:", bmi_count)
total_values = len(test_data['bmi'])
print("Total number of values in the 'bmi' column:", total_values)
print(total_values - bmi_count)
# Out:
# Number of non-empty values in the 'bmi' column: 1777
# Total number of values in the 'bmi' column: 5792
# 4015

# %% [markdown]
# We generate a bar plot illustrating the average bmi across various patient races in the dataset. Each bar represents the average bmi for a specific patient race category.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
avg_bmi_by_race = train_data.groupby('patient_race')['bmi'].mean().reset_index()
plt.figure(figsize=(10, 6))
sns.barplot(x='patient_race', y='bmi', data=avg_bmi_by_race, palette='Set2')
plt.title('Average BMI Across Patient Race (TRAIN DATA)')
plt.xlabel('Patient Race')
plt.ylabel('Average BMI')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
avg_bmi_by_state = train_data.groupby('patient_state')['bmi'].mean().reset_index()
plt.figure(figsize=(15, 6))
sns.barplot(x='patient_state', y='bmi', data=avg_bmi_by_state, palette='Set3')
plt.title('Average BMI Across Patient States (TRAIN DATA)')
plt.xlabel('Patient State')
plt.ylabel('Average BMI')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
avg_bmi_by_diagnosis_code = train_data.groupby('metastatic_cancer_diagnosis_code')['bmi'].mean().reset_index()
plt.figure(figsize=(10, 6))
sns.barplot(x='metastatic_cancer_diagnosis_code', y='bmi', data=avg_bmi_by_diagnosis_code, palette='Set3')
plt.title('Average BMI Across Metastatic Cancer Diagnosis Codes (TRAIN DATA)')
plt.xlabel('Metastatic Cancer Diagnosis Code')
plt.ylabel('Average BMI')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
treatment_count = train_data['metastatic_first_novel_treatment'].notnull().sum()
print("Number of non-empty values in the 'metastatic_first_novel_treatment' column:", treatment_count)
total_values = len(train_data['metastatic_first_novel_treatment'])
print("Total number of values in the 'metastatic_first_novel_treatment' column:", total_values)
print("Number of empty values in the 'metastatic_first_novel_treatment' column:", total_values - treatment_count)
# Out:
# Number of non-empty values in the 'metastatic_first_novel_treatment' column: 24
# Total number of values in the 'metastatic_first_novel_treatment' column: 12906
# Number of empty values in the 'metastatic_first_novel_treatment' column: 12882

# %%
treatment_type_count = train_data['metastatic_first_novel_treatment_type'].notnull().sum()
print("Number of non-empty values in the 'metastatic_first_novel_treatment_type' column:", treatment_type_count)
total_values_type = len(train_data['metastatic_first_novel_treatment_type'])
print("Total number of values in the 'metastatic_first_novel_treatment_type' column:", total_values_type)
print("Number of empty values in the 'metastatic_first_novel_treatment_type' column:", total_values_type - treatment_type_count)
# Out:
# Number of non-empty values in the 'metastatic_first_novel_treatment_type' column: 24
# Total number of values in the 'metastatic_first_novel_treatment_type' column: 12906
# Number of empty values in the 'metastatic_first_novel_treatment_type' column: 12882

# %% [markdown]
# The columns 'metastatic_first_novel_treatment' and 'metastatic_first_novel_treatment_type' contain very few non-empty values compared to the total number of entries. Given this imbalance, and considering that they do not provide meaningful information for predicting individuals diagnosed in less than 90 days, we should drop these columns from the dataset.
